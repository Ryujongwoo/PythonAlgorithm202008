# %%
from IPython.display import Image
Image('./selectionSort.png', width = '1000', height = '1000')

# %%
sortData = [8, 3, 4, 9, 1]
for i in range(len(sortData) - 1):
    for j in range(i + 1, len(sortData)):
        # print('i = {}, j = {}'.format(i, j))
        # 부등호를 '<'로 변경하면 내림차순으로 정렬된다.
        if sortData[i] > sortData[j]:
            # temp = sortData[i]
            # sortData[i] = sortData[j]
            # sortData[j] = temp
            sortData[i], sortData[j] = sortData[j], sortData[i]
        # ============= if sortData[i] > sortData[j]: 끝
    # ============= for j in range(i + 1, 5): 끝 => 회전 끝
    print('{}회전 결과 : {}'.format(i + 1, sortData))
# ============= for i in range(4): 끝 => 정렬 끝
# print('정렬 결과 : {}'.format(sortData))
# Out:
# 1회전 결과 : [1, 8, 4, 9, 3]
# 2회전 결과 : [1, 3, 8, 9, 4]
# 3회전 결과 : [1, 3, 4, 9, 8]
# 4회전 결과 : [1, 3, 4, 8, 9]

# %%
sortData = [8, 3, 4, 9, 1]
sortData.sort() # 오름차순 정렬
print(sortData)
sortData.sort(reverse = True) # 내림차순 정렬
print(sortData)
# Out:
# [1, 3, 4, 8, 9]
# [9, 8, 4, 3, 1]
