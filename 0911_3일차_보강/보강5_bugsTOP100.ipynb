# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now()) # 현재 컴퓨터의 날짜와 시간을 얻어온다.
print(dt.now().year)
print(dt.now().month)
print(dt.now().day)
print(dt.now().hour)
print(dt.now().minute)
print(dt.now().second)
print(dt.now().microsecond)
print(dt.now().microsecond // 1000) # 밀리초
# Out:
# 2020-09-11 20:21:46.008783
# 2020
# 9
# 11
# 20
# 21
# 46
# 9781
# 9

# %%
targetSite = 'https://music.bugs.co.kr/chart'

# %%
request = requests.get(targetSite)
# print(request)
html = request.text
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <!-- bgsweb-www905 -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="음악,음악 스트리밍,최신음악,인기가요,뮤직비디오,앨범,플레이어,mp3 다운로드,놀면뭐하니,유플래쉬,유플래시" name="keywords">
# <script type="text/javascript">
# 	if(!(location.href.indexOf("music.bugs.co.kr/newPlayer") >= 0 || location.href.indexOf("music.bugs.co.kr/newRadio") >= 0 || location.href.indexOf("localhost") >= 0))
# 		document.domain = 'bugs.co.kr';
#
# 	var g_urlBase = "https://www.bugs.co.kr";
# 	var g_urlWww = "https://www.bugs.co.kr";
# 	var g_urlSecure = "https://secure.bugs.co.kr";
# 	var g_urlMusic = "https://music.bugs.co.kr";
# 	var g_urlMusicSecure = "https://music.bugs.co.kr";
# 	var g_urlMember = "https://secure.bugs.co.kr/member";
# 	var g_urlFile = "https://file.bugsm.co.kr/wbugs";
# 	var g_urlFile_n ="https://file.bugsm.co.kr/nbugs";
# 	//var g_urlSwf = "https://music.bugs.co.kr/swf";
# 	var g_urlSwf = "https://music.bugs.co.kr/swf";
# ...

# %%
# 노래 제목 크롤링
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))
for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# Dynamite
# Sweet Love (취향저격 그녀 X Crush)
# WANNA BE MYSELF
# 숲의 아이 (Bon voyage)
# Ice Cream (with Selena Gomez)
# 밤새 (취향저격 그녀 X 카더가든)
# Not Shy
# When We Disco (Duet with 선미)
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 취기를 빌려 (취향저격 그녀 X 산들)
# 눈누난나 (NUNU NANA)
# 덤디덤디 (DUMDi DUMDi)
# 마리아 (Maria)
# 다시 여기 바닷가
# 에잇(Prod.&Feat. SUGA of BTS)
# Dolphin
# 홀로
# 오래된 노래
# How You Like That
# 축하해
# HAVE A GOODNIGHT (취향저격 그녀 X 셔누 (몬스타엑스), 민혁 (몬스타엑스))
# 파도가 끝나는 곳까지
# 거짓말이라도 해서 널 보고싶어
# Downtown Baby
# 아틀란티스 소녀 (Atlantis Princess)
# 보라빛 밤 (pporappippam)
# 살짝 설렜어 (Nonstop)
# Criminal
# 그 여름을 틀어줘
# 12:45 (Stripped)
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# Obliviate
# 어떻게 지내 (Prod. By VAN.C)
# Dance Monkey
# Blueming
# Watermelon Sugar
# 아로하
# LINDA (Feat. 윤미래)
# Memories
# 좋은 사람 있으면 소개시켜줘
# METEOR
# 사랑하게 될 줄 알았어
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# Summer Hate (Feat. 비)
# PLAY (Feat. 창모)
# Square (2017)
# Into the I-LAND
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 신난다 (Feat. 마마무)
# Maniac
# Juice
# 여름 안에서 by 싹쓰리 (Feat. 황광희)
# ...

# %%
# 아티스트 크롤링
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
# print(len(artists))
for artist in artists:
    # print(artist.text.strip())
    # print(artist.text.split('\n')[1])
    print(artist.text.strip().split('\n')[0])
# Out:
# 방탄소년단
# Crush
# 마마무(Mamamoo)
# 유아 (오마이걸)
# BLACKPINK
# 카더가든
# ITZY (있지)
# 박진영
# 규현 (KYUHYUN)
# 산들
# 제시(Jessi)
# (여자)아이들
# 화사(Hwa Sa)
# 싹쓰리 (유두래곤, 린다G, 비룡)
# 아이유(IU)
# 오마이걸(OH MY GIRL)
# 이하이
# 스탠딩 에그(Standing Egg)
# BLACKPINK
# 오반
# 셔누
# DAY6 (Even of Day)
# 백지영
# 블루(BLOO)
# 볼빨간사춘기
# 선미
# 오마이걸(OH MY GIRL)
# 태민 (TAEMIN)
# 싹쓰리 (유두래곤, 린다G, 비룡)
# Etham
# 장범준
# 러블리즈(Lovelyz)
# 오반
# Tones And I
# 아이유(IU)
# Harry Styles(해리 스타일스)
# 조정석
# 린다G
# Maroon 5(마룬 파이브)
# 조이 (JOY)
# 창모(CHANGMO)
# 전미도
# 방탄소년단
# 지코
# 청하
# 백예린
# 아이유(IU)
# AKMU (악동뮤지션)
# 비룡
# Conan Gray
# Lizzo
# 싹쓰리 (유두래곤, 린다G, 비룡)
# 에이프릴(APRIL)
# Red Velvet (레드벨벳)
# Lauv(라우브)
# Anne-Marie(앤 마리)
# 전소미
# Dua Lipa(두아 리파)
# Ruel(루엘)
# Sam Smith(샘 스미스)
# 폴킴(Paul Kim)
# David Guetta(데이빗 게타)
# 아이유(IU)
# 폴킴(Paul Kim)
# Ariana Grande(아리아나 그란데)
# 전상근
# 임영웅
# TWICE (트와이스)
# 잔나비
# 레드벨벳-아이린&슬기
# 규현 (KYUHYUN)
# 임영웅
# Crush
# 지코
# 이수현
# 볼빨간사춘기
# Red Velvet (레드벨벳)
# 마크툽(MAKTUB)
# 마크툽(MAKTUB)
# 노을
# 아이유(IU)
# SuperM
# 아이유(IU)
# ITZY (있지)
# 가호(Gaho)
# ...

# %%
print(dt.now())
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print("{0:3d}위 {1} - {2}".format(i + 1, artist, title))
# Out:
# 2020-09-11 20:21:47.286143
#   1위 방탄소년단 - Dynamite
#   2위 Crush - Sweet Love (취향저격 그녀 X Crush)
#   3위 마마무(Mamamoo) - WANNA BE MYSELF
#   4위 유아 (오마이걸) - 숲의 아이 (Bon voyage)
#   5위 BLACKPINK - Ice Cream (with Selena Gomez)
#   6위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
#   7위 ITZY (있지) - Not Shy
#   8위 박진영 - When We Disco (Duet with 선미)
#   9위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  10위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  11위 제시(Jessi) - 눈누난나 (NUNU NANA)
#  12위 (여자)아이들 - 덤디덤디 (DUMDi DUMDi)
#  13위 화사(Hwa Sa) - 마리아 (Maria)
#  14위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
#  15위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
#  16위 오마이걸(OH MY GIRL) - Dolphin
#  17위 이하이 - 홀로
#  18위 스탠딩 에그(Standing Egg) - 오래된 노래
#  19위 BLACKPINK - How You Like That
#  20위 오반 - 축하해
#  21위 셔누 - HAVE A GOODNIGHT (취향저격 그녀 X 셔누 (몬스타엑스), 민혁 (몬스타엑스))
#  22위 DAY6 (Even of Day) - 파도가 끝나는 곳까지
#  23위 백지영 - 거짓말이라도 해서 널 보고싶어
#  24위 블루(BLOO) - Downtown Baby
#  25위 볼빨간사춘기 - 아틀란티스 소녀 (Atlantis Princess)
#  26위 선미 - 보라빛 밤 (pporappippam)
# ...

# %%
# 크롤링한 결과를 텍스트 파일로 저장한다.
# 크롤링한 데이터를 텍스트 파일에 저장하려는 경우 아래와 같이 파일을 열면 한글 인코딩 문제로 UnicodeEncodeError가 발생될 수 있다.
# open() 함수를 사용해서 파일을 출력용으로 열어준다.
file = open('bugsTOP100.txt', 'w')
# UnicodeEncodeError: 'cp949' codec can't encode character '\xf1' in position 29: illegal multibyte sequence 에러가 발생되면 아래와 같이 파일을 
# open 해서 저장하면 정상적으로 잘 처리가 된다.
# file = open('bugsTOP100.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))

for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    data = "{0:3d}위 {1} - {2}".format(i + 1, artist, title)
    file.write(data + '\n')

# 출력용 파일은 작업이 완료되면 반드시 close() 메소드를 사용해 닫아야 정상적으로 파일로 데이터가 저장된다.
file.close()
print('BugsTOP100.txt 파일에 쓰기 완료')
# Out:
# BugsTOP100.txt 파일에 쓰기 완료

# %%
# 텍스트 파일에 저장된 크롤링 데이터를 읽어서 화면에 출력한다.
file = open('bugsTOP100.txt', 'r')
# readlines() 메소드는 텍스트 파일의 내용 전체를 한꺼번에 읽어서 list로 반환한다.
lines = file.readlines()
# print(type(lines))
for line in lines:
    # print(line, end = '')
    print(line.strip())
file.close()
# Out:
# 2020-09-11 20:21:47.299144 현재 Bugs 뮤직 실시간 TOP 100
# 1위 방탄소년단 - Dynamite
# 2위 Crush - Sweet Love (취향저격 그녀 X Crush)
# 3위 마마무(Mamamoo) - WANNA BE MYSELF
# 4위 유아 (오마이걸) - 숲의 아이 (Bon voyage)
# 5위 BLACKPINK - Ice Cream (with Selena Gomez)
# 6위 카더가든 - 밤새 (취향저격 그녀 X 카더가든)
# 7위 ITZY (있지) - Not Shy
# 8위 박진영 - When We Disco (Duet with 선미)
# 9위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 10위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 11위 제시(Jessi) - 눈누난나 (NUNU NANA)
# 12위 (여자)아이들 - 덤디덤디 (DUMDi DUMDi)
# 13위 화사(Hwa Sa) - 마리아 (Maria)
# 14위 싹쓰리 (유두래곤, 린다G, 비룡) - 다시 여기 바닷가
# 15위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
# 16위 오마이걸(OH MY GIRL) - Dolphin
# 17위 이하이 - 홀로
# 18위 스탠딩 에그(Standing Egg) - 오래된 노래
# 19위 BLACKPINK - How You Like That
# 20위 오반 - 축하해
# 21위 셔누 - HAVE A GOODNIGHT (취향저격 그녀 X 셔누 (몬스타엑스), 민혁 (몬스타엑스))
# 22위 DAY6 (Even of Day) - 파도가 끝나는 곳까지
# 23위 백지영 - 거짓말이라도 해서 널 보고싶어
# 24위 블루(BLOO) - Downtown Baby
# 25위 볼빨간사춘기 - 아틀란티스 소녀 (Atlantis Princess)
# 26위 선미 - 보라빛 밤 (pporappippam)
# ...
